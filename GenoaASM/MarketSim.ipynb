# %%
import numpy as np
#from matplotlib import pyplot as plt
#import GenoaMarket library
import GenoaMarket
#import DType to use diffrent initial scenarios
from GenoaMarket.misc import DType
from time import perf_counter

#seed for consistancy
np.random.seed(100)

#initialize 2 Markets with N default agents
N = 20

genoa_basic = GenoaMarket.Market(N=N,init_price=10,pa=0.0002,pc=0.1)
#genoa_royal = GenoaMarket.Market(N=N,init_price=100,pa=0.0002,pc=0.1)

#Initialize the market resources distribution
#start with 100 dollars per agent and 20 stocks per agent
genoa_basic.distribute(C=100*N,A = 20*N,dtype=DType.UNIFORM)
#genoa_royal.distribute(C=1000*N,A = 20*N,dtype=DType.ROYALTY)

# %%
# simulation
total_steps = 10

genoa_basic.simulate(tau=total_steps)
#genoa_royal.simulate(tau=tau)
# Out:
# Equilibrium price : 7.423065606264675
# Equilibrium price : 5.25960401189542
# Equilibrium price : 3.5468044071893727
# Equilibrium price : 3.698555352236363
# Equilibrium price : 2.709893493362571
# Equilibrium price : 3.1707001521530374
# Equilibrium price : 2.2870647522314056
# Equilibrium price : 2.2188989818885987
# Equilibrium price : 3.268914353684145
# Equilibrium price : 3.9144135121284127
# Ran 10 simulation steps for 20 agents over a period of 0:00:01.881176

# %%
#get the prices
basic_prices, royal_prices = np.array(genoa_basic.prices), np.array(genoa_royal.prices)
#get the log price returns
log_price_returns = lambda array : np.log(array[1:]/array[:-1])

# %%
fig, axs = plt.subplots(figsize=(15,5))
axs.set_title(rf"Log price returns of Uniform and Royal Distribution of resources (N={N}, $\tau$={tau})")

#plot the two series
axs.plot(log_price_returns(basic_prices),label="Uniform distribution",linewidth=0.5,alpha=0.5)
axs.plot(log_price_returns(royal_prices),label="Royalty distribution",linewidth=0.5,alpha=0.5)

#axs.set_xlim((1,10000))
#axs.set_ylim((-0.15,0.15))
axs.set_ylabel("Log price returns")
axs.set_xlabel("Time step")
axs.legend()
plt.savefig("pics/log_price_returns.png")
plt.show()
